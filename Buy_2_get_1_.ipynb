# %% [markdown]
# # Apriori

# %% [markdown]
# ## Importing the libraries

# %%
# !pip install apyori

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Data Preprocessing

# %%
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)
transactions = []
for i in range(0, 7501):
  transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %%
transactions
# Out:
# ['burgers',
#  'meatballs',
#  'eggs',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan']

# %%
cleanedList = [] 
for x in transactions:
  cleanedList.append([i for i in x if str(i) != 'nan'])

# %%
cleanedList
# Out:
# ['burgers', 'meatballs', 'eggs']

# %% [markdown]
# ## Training the Apriori model on the dataset

# %%
from apyori import apriori
rules = apriori(transactions = cleanedList, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 3, max_length = 3)

# %% [markdown]
# ### Displaying the first results coming directly from the output of the apriori function

# %%
results = list(rules)

# %%
results

# %% [markdown]
# ### Putting the results well organised into a Pandas DataFrame

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0]) for result in results]
    rhs         = [tuple(result[2][0][1]) for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))    
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %% [markdown]
# ### Displaying the results non sorted

# %%
resultsinDataFrame
# Out:
#                         Left Hand Side  ...      Lift
# 0                       (light cream,)  ...  4.843951
# 1              (mushroom cream sauce,)  ...  3.790833
# 2                             (pasta,)  ...  4.700812
# 3                     (fromage blanc,)  ...  5.164271
# 4                     (herb & pepper,)  ...  3.291994
# 5                      (tomato sauce,)  ...  3.840659
# 6                       (light cream,)  ...  3.114710
# 7                 (whole wheat pasta,)  ...  4.122410
# 8                             (pasta,)  ...  4.506672
# 9                 (avocado, spaghetti)  ...  3.215449
# 10                        (milk, cake)  ...  3.211437
# 11                 (chocolate, turkey)  ...  3.103490
# 12                      (turkey, milk)  ...  3.238424
# 13           (cake, frozen vegetables)  ...  4.367560
# 14              (cereals, ground beef)  ...  3.885303
# 15              (chicken, ground beef)  ...  3.152046
# ...

# %%
resultsinDataFrame

# %% [markdown]
# ### Displaying the results sorted by descending lifts

# %%
resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
# Out:
#                         Left Hand Side  ...      Lift
# 52  (whole wheat pasta, mineral water)  ...  6.115863
# 44                     (tomato sauce,)  ...  5.535971
# 3                     (fromage blanc,)  ...  5.164271
# 0                       (light cream,)  ...  4.843951
# 2                             (pasta,)  ...  4.700812
# 24         (ground beef, french fries)  ...  4.665768
# 8                             (pasta,)  ...  4.506672
# 19          (chocolate, herb & pepper)  ...  4.490183
# 13           (cake, frozen vegetables)  ...  4.367560
# 49                    (milk, tomatoes)  ...  4.335293
#
# [10 rows x 5 columns]
